# %%
import pandas as pd, numpy as np

from matplotlib import pyplot as plt
import matplotlib.dates as mdates
myFmt = mdates.DateFormatter('%a\n%m/%d')

import seaborn as sns

# %%
pd.options.display.max_rows = 999

# %%
from sklearn.linear_model import LinearRegression

# %%
# Import COVID data from the NY Times
path = "https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv"
covid = pd.read_csv(path)
covid['date'] = pd.to_datetime(covid.date)

# Import census population data by county for 2018
path = 'http://www.wtad.com/assets/news_files/PEP_2018_PEPANNCHG.ST05_with_ann.xlsx'
pop = pd.read_excel(path)
pop = pop.rename(columns={'GC.target-geo-id2':'fips',
                'respop72018':'population'})
pop = pop[['fips','population']]
pop = pop.loc[1:]
pop['population'] = pd.to_numeric(pop['population'])
pop['fips'] = pd.to_numeric(pop.fips)

# %%
# Import MSA mapping 
# Clean up MSA names to keep the major city and state
path = "https://raw.githubusercontent.com/dri3s/covidviz/master/metrolist.csv"
msa = pd.read_csv(path, nrows=1160, header=None, names=['msa_fips','msa_name','fips','county_name'])

msa.fips = pd.to_numeric(msa['fips'])
msa = msa.drop(columns=['msa_fips','county_name'])

msasplit = msa.msa_name.str.split(pat=',|-', expand=True)
msasplit['state'] = None

for idx, row in msasplit.iterrows():
    for col in row:
        try:
            state = col.strip()[0:2]
            if state.isupper() and msasplit.loc[idx, 'state'] == None:
                msasplit.loc[idx, 'state'] = state
                continue
        except:
            continue

msasplit = msasplit.rename(columns={0:'city'})

msasplit = msasplit[['city','state']]
msa[['city','state']] = msasplit
msa['msa_name'] = msa.city + ', ' + msa.state

# %%
# Make sure there are records for every single day - fill null values with zeroes
calshell = pd.DataFrame(covid.date.unique(), columns=['date'])
calshell['key'] = 1
pop['key'] = 1
covidmsa = calshell.merge(pop).merge(msa).merge(covid, how='left', on=['fips','date'])
covidmsa = covidmsa.fillna(0)

# %%
# Combine covid, population, and MSA data
# Sum by MSA and compute cases per capita
covidmsa = covidmsa.drop(columns=['fips','key']).groupby(['date','msa_name']).sum().reset_index()
covidmsa['caseperk'] = (covidmsa.cases/covidmsa['population']) * 1000
covidmsa = covidmsa.sort_values(by=['msa_name','date']).reset_index(drop=True)
covidmsa = covidmsa.loc[covidmsa.cases >= 10]
covidmsa ['num_days'] = (covidmsa.date - covidmsa.groupby(['msa_name'])['date'].transform('min')).dt.days

# %%
covidmsa.loc[covidmsa.date == covidmsa.date.max()].sort_values('caseperk')
# Out:
#             date          msa_name  population     cases  deaths   caseperk  \
# 5809  2020-04-12         Chico, CA      231256      14.0     0.0   0.060539
# 12366 2020-04-12       Hanford, CA      151366      10.0     1.0   0.066065
# 30377 2020-04-12        Wausau, WI      163117      13.0     1.0   0.079697
# 31622 2020-04-12          Yuma, AZ      212128      17.0     0.0   0.080140
# 746   2020-04-12       Altoona, PA      122492      10.0     0.0   0.081638
# ...          ...               ...         ...       ...     ...        ...
# 3900  2020-04-12    Bridgeport, CT      943823    5534.0   248.0   5.863388
# 20583 2020-04-12      New York, NY    19303808  127205.0  4504.0   6.589632
# 22990 2020-04-12  Poughkeepsie, NY      675669    6865.0   142.0  10.160300
# 20500 2020-04-12   New Orleans, LA     1270399   13105.0   540.0  10.315657
# 248   2020-04-12        Albany, GA      149917    1618.0   101.0  10.792639
#
#        num_days
# 5809         10
# 12366         1
# 30377         8
# 31622        13
# 746           1
# ...         ...
# 3900         29
# 20583        39
# 22990        29
# 20500        32
# 248          24
#
# [373 rows x 7 columns]

# %%
# Mark the 10 worst MSAs and include others of interest
worst = list(covidmsa.groupby('msa_name').
             caseperk.max().reset_index().
             sort_values('caseperk').tail(10).msa_name.values)

dets = list(covidmsa.loc[covidmsa.msa_name.str.contains('Dallas')].msa_name.unique())
dets.append(covidmsa.loc[covidmsa.msa_name.str.contains('Houston')].msa_name.unique()[0])

# These are cities with quarantine facilities that had lots of patients early on 
# They are outliers and should be excluded
exclude = ['San Antonio, TX','Omaha, NE','Vallejo, CA']

# %%
exp = pd.DataFrame(np.arange(40), columns=['num_days'])
ds = list(range(3, 9))
for d in ds:
    exp['double{}'.format(d)] = 10 * np.exp(exp.num_days * (np.log(2)/d))

colors = iter(sns.color_palette('husl', len(worst) + len(dets)))

plt.rcParams['figure.figsize'] = 15, 5
fig, ax = plt.subplots()

for d in ds:
    ys = exp['double{}'.format(d)]
    ax.plot(exp.num_days, ys, ls='dotted', color='red')
    plt.text(exp.num_days.max() + 1, ys.max(), 'x2 ~ {} days'.format(d))


i = 0

for msaname, df in covidmsa.groupby('msa_name'):    
    if msaname in exclude:
        continue
    
    df = df.sort_values(by='caseperk')
    
    if msaname in worst or msaname in dets:
        label = msaname
        color = next(colors)
        lw, alpha = (3, 1)
        
        if i%2 == 0: ls = '--'
        else: ls = '-'
            
        i += 1
    else:   
        continue
        label = '_nolabel_'
        color='gray'
        lw, alpha = (0.4, 0.4)
        ls = '-'
        
    if msaname in dets:        
        #lw = 5    
        pass
    
    #ax.plot(covidmsa.loc[covidmsa.fips == fips]['date'],
    ax.plot(df['num_days'],
            df['cases'], 
            label=label,
            color=color,
            lw=lw,
            alpha=alpha,
            ls = ls
            )    
    
    
#ax.set_xlim([pd.to_datetime('15feb2020'),pd.to_datetime(date.today())])
#ax.xaxis.set_major_formatter(myFmt)
#ax.xaxis.set_major_locator(mdates.WeekdayLocator(mdates.MO))

#ax.set_xlim([0, covidmsa.num_days.max()])

ax.set_yscale('log')

ax.set_ylabel('COVID Cases per 1,000 people')
ax.set_xlabel('Num Days Since 10th Case')
ax.legend()
ax.grid()

plt.figtext(0.9, 0.01, 'Data current through {:%m/%d}'.format(covidmsa.date.max()), horizontalalignment='right')
# Out:
# Text(0.9, 0.01, 'Data current through 04/12')

# %%
    df = covidmsa.loc[covidmsa.msa_name == "New York, NY"].copy()

# %%
def GetDouble(df):
    df['lncase'] = np.log(df.cases)
    df = df.sort_values(by='date')

    X = df.tail(5).num_days.values.reshape(-1, 1)
    y = df.tail(5).lncase.values

    reg = LinearRegression().fit(X, y)

    return round(np.log(2)/reg.coef_[0], 1)

# %%
doubling = covidmsa.groupby('msa_name').apply(lambda x: GetDouble(x)).reset_index()
# Out:
# <ipython-input-179-403f4b8ba6a7>:10: RuntimeWarning: divide by zero encountered in double_scalars
#   return round(np.log(2)/reg.coef_[0], 1)
# <ipython-input-179-403f4b8ba6a7>:10: RuntimeWarning: divide by zero encountered in double_scalars
#   return round(np.log(2)/reg.coef_[0], 1)
# <ipython-input-179-403f4b8ba6a7>:10: RuntimeWarning: divide by zero encountered in double_scalars
#   return round(np.log(2)/reg.coef_[0], 1)
# <ipython-input-179-403f4b8ba6a7>:10: RuntimeWarning: divide by zero encountered in double_scalars
#   return round(np.log(2)/reg.coef_[0], 1)
# <ipython-input-179-403f4b8ba6a7>:10: RuntimeWarning: divide by zero encountered in double_scalars
#   return round(np.log(2)/reg.coef_[0], 1)
# <ipython-input-179-403f4b8ba6a7>:10: RuntimeWarning: divide by zero encountered in double_scalars
#   return round(np.log(2)/reg.coef_[0], 1)

# %%
doubling = doubling.rename(columns={0: 'doubling'})

# %%
doubling = doubling.loc[doubling.doubling != np.inf]

# %%
doubling = doubling.sort_values(by='doubling').reset_index(drop=True)

# %%
doubling
# Out:
#                             msa_name  doubling
# 0                        Decatur, IL       2.9
# 1                       Waterloo, IA       3.0
# 2                        Reading, PA       3.1
# 3                   Grand Island, NE       3.3
# 4                    Sioux Falls, SD       3.5
# 5                      Goldsboro, NC       3.7
# 6                        Abilene, TX       3.8
# 7                       Vineland, NJ       3.9
# 8                  Elizabethtown, KY       4.1
# 9                     Sioux City, IA       4.7
# 10                      New Bern, NC       4.8
# 11                        Mobile, AL       4.8
# 12                        Merced, CA       4.8
# 13                       Elkhart, IN       4.9
# 14                   Brownsville, TX       4.9
# 15                    Bloomsburg, PA       5.0
# 16                     Salisbury, MD       5.1
# 17                       Gadsden, AL       5.2
# 18                   Tallahassee, FL       5.3
# 19                       El Paso, TX       5.3
# 20                    Huntington, WV       5.4
# 21                      Columbus, IN       5.4
# 22                       Hickory, NC       5.5
# 23                       Augusta, GA       5.7
# 24                 Bowling Green, KY       5.7
# 25                       Norwich, CT       5.8
# 26                        Dothan, AL       5.8
# 27                   Hattiesburg, MS       5.9
# 28                       Lebanon, PA       6.0
# 29                    Fort Wayne, IN       6.1
# 30                       Killeen, TX       6.1
# 31                      Columbus, GA       6.1
# 32                       Trenton, NJ       6.2
# 33                   Springfield, OH       6.2
# 34                     Worcester, MA       6.2
# 35                   Punta Gorda, FL       6.2
# 36                  Sierra Vista, AZ       6.3
# 37                     Wenatchee, WA       6.3
# 38                   Rocky Mount, NC       6.3
# 39                    Cumberland, MD       6.3
# 40               Charlottesville, VA       6.5
# 41                       McAllen, TX       6.5
# 42                        Racine, WI       6.5
# 43                      Hartford, CT       6.6
# 44                     New Haven, CT       6.6
# 45                    Providence, RI       6.6
# 46                      Wheeling, WV       6.7
# 47                    San Angelo, TX       6.7
# 48                        Boston, MA       6.7
# 49                  Williamsport, PA       6.8
# 50                 Atlantic City, NJ       6.9
# 51                      Rockford, IL       7.0
# 52                         Fargo, ND       7.0
# 53                       Saginaw, MI       7.0
# 54                      Kingston, NY       7.0
# 55                      Florence, SC       7.0
# 56                        Muncie, IN       7.1
# 57                    Washington, DC       7.1
# 58                      Amarillo, TX       7.1
# 59                   Glens Falls, NY       7.2
# 60                     Mansfield, OH       7.2
# 61                  Battle Creek, MI       7.2
# 62                   Springfield, MA       7.3
# 63                     Green Bay, WI       7.3
# 64                     Johnstown, PA       7.3
# 65                       Lubbock, TX       7.4
# 66                   Idaho Falls, ID       7.4
# 67                    Greenville, SC       7.4
# 68                       Raleigh, NC       7.5
# 69                   Gainesville, FL       7.5
# 70                  Chambersburg, PA       7.5
# 71                         Utica, NY       7.5
# 72                        Odessa, TX       7.6
# 73                    Ocean City, NJ       7.6
# 74                       Houston, TX       7.6
# 75                     Lynchburg, VA       7.6
# 76                         Niles, MI       7.7
# 77                    Gettysburg, PA       7.7
# 78                    Tuscaloosa, AL       7.7
# 79                  Philadelphia, PA       7.7
# 80                      Bay City, MI       7.8
# 81                     Davenport, IA       7.8
# 82                        Casper, WY       7.8
# 83                   Albuquerque, NM       7.8
# 84                    Montgomery, AL       7.9
# 85                          Lima, OH       7.9
# 86                      Beaumont, TX       8.0
# 87                   Minneapolis, MN       8.0
# 88                        Topeka, KS       8.1
# 89                    Binghamton, NY       8.1
# 90                      Kankakee, IL       8.1
# 91                     Baltimore, MD       8.1
# 92                    Twin Falls, ID       8.1
# 93                        Daphne, AL       8.1
# 94                   Spartanburg, SC       8.2
# 95                        Duluth, MN       8.2
# 96                         Dover, DE       8.2
# 97                   Clarksville, TN       8.4
# 98                   San Antonio, TX       8.4
# 99                     Kennewick, WA       8.5
# 100                      Chicago, IL       8.5
# 101                   South Bend, IN       8.5
# 102                       Durham, NC       8.6
# 103                      Modesto, CA       8.6
# 104                       Toledo, OH       8.6
# 105                 Myrtle Beach, SC       8.6
# 106                   Carbondale, IL       8.6
# 107                    Lancaster, PA       8.7
# 108                      Visalia, CA       8.7
# 109                 Lake Charles, LA       8.8
# 110                      Jackson, MS       8.8
# 111                         Erie, PA       8.8
# 112                        Flint, MI       8.9
# 113                    Owensboro, KY       8.9
# 114                         Napa, CA       8.9
# 115                       Peoria, IL       9.0
# 116                     Richmond, VA       9.0
# 117                      Lincoln, NE       9.1
# 118                    Kingsport, TN       9.1
# 119                       Denver, CO       9.1
# 120                       Yakima, WA       9.1
# 121                    Iowa City, IA       9.1
# 122                      Jackson, MI       9.1
# 123                         Reno, NV       9.1
# 124                  Hot Springs, AR       9.2
# 125                   Youngstown, OH       9.2
# 126                     Muskegon, MI       9.2
# 127                   Harrisburg, PA       9.2
# 128                    Riverside, CA       9.3
# 129                       Laredo, TX       9.3
# 130                     Victoria, TX       9.3
# 131                   Burlington, NC       9.4
# 132                  Bloomington, IN       9.4
# 133                  Parkersburg, WV       9.4
# 134                       Monroe, LA       9.4
# 135                       Tucson, AZ       9.5
# 136                        Ocala, FL       9.5
# 137                    Asheville, NC       9.5
# 138                       Canton, OH       9.6
# 139                   St. Joseph, MO       9.6
# 140                 Grand Rapids, MI       9.8
# 141                     Columbia, SC       9.8
# 142                         York, PA       9.8
# 143                      Weirton, WV       9.9
# 144                   St. George, UT       9.9
# 145                 Poughkeepsie, NY       9.9
# 146                       Joplin, MO       9.9
# 147                   Janesville, WI      10.0
# 148                   Farmington, NM      10.0
# 149                    St. Louis, MO      10.1
# 150                      Memphis, TN      10.2
# 151                   North Port, FL      10.2
# 152                       Albany, NY      10.3
# 153                     Scranton, PA      10.3
# 154                   California, MD      10.3
# 155               Salt Lake City, UT      10.4
# 156              College Station, TX      10.4
# 157                    Anchorage, AK      10.4
# 158                   Hagerstown, MD      10.5
# 159                    Flagstaff, AZ      10.5
# 160                       Fresno, CA      10.6
# 161                   Evansville, IN      10.6
# 162                   Cape Coral, FL      10.6
# 163                  Baton Rouge, LA      10.6
# 164            Homosassa Springs, FL      10.6
# 165                 Indianapolis, IN      10.6
# 166                      Jackson, TN      10.7
# 167                       Austin, TX      10.7
# 168  Louisville/Jefferson County, KY      10.7
# 169                    Pensacola, FL      10.7
# 170                        Macon, GA      10.7
# 171                Oklahoma City, OK      10.8
# 172                       Dallas, TX      10.8
# 173                      Sebring, FL      10.8
# 174                       Naples, FL      10.8
# 175                        Miami, FL      10.8
# 176                  Walla Walla, WA      10.9
# 177                 Fayetteville, NC      10.9
# 178                      Roanoke, VA      10.9
# 179             Lake Havasu City, AZ      10.9
# 180                    Champaign, IL      11.0
# 181                   Hinesville, GA      11.0
# 182                   Manchester, NH      11.1
# 183                     Cheyenne, WY      11.1
# 184                  Kansas City, MO      11.1
# 185                    Lafayette, LA      11.2
# 186                    Rochester, MN      11.2
# 187                     Billings, MT      11.2
# 188                 Jacksonville, NC      11.2
# 189                      Boulder, CO      11.3
# 190                        Houma, LA      11.3
# 191                      Greeley, CO      11.3
# 192                  Panama City, FL      11.3
# 193                     New York, NY      11.4
# 194                   Des Moines, IA      11.4
# 195                  Bakersfield, CA      11.4
# 196                      Hammond, LA      11.4
# 197                     Gulfport, MS      11.4
# 198                      Buffalo, NY      11.4
# 199                      Salinas, CA      11.4
# 200                  Terre Haute, IN      11.5
# 201                    Allentown, PA      11.5
# 202             Colorado Springs, CO      11.5
# 203                   Charleston, WV      11.5
# 204                        Omaha, NE      11.6
# 205                    Lafayette, IN      11.6
# 206                   Burlington, VT      11.6
# 207                  Springfield, IL      11.6
# 208                   Cincinnati, OH      11.7
# 209                      Wichita, KS      11.8
# 210                      Midland, MI      11.9
# 211                     Palm Bay, FL      12.0
# 212                      Phoenix, AZ      12.1
# 213                State College, PA      12.2
# 214               Cape Girardeau, MO      12.2
# 215                     Columbus, OH      12.3
# 216                   Las Cruces, NM      12.3
# 217                       Pueblo, CO      12.3
# 218                       Sumter, SC      12.4
# 219                   Bridgeport, CT      12.5
# 220                    Crestview, FL      12.5
# 221                       Dalton, GA      12.6
# 222                        Akron, OH      12.7
# 223                    Las Vegas, NV      12.8
# 224                        Salem, OR      12.8
# 225                   Pittsfield, MA      12.9
# 226                   Shreveport, LA      12.9
# 227                       Dayton, OH      13.0
# 228               Virginia Beach, VA      13.1
# 229                   Birmingham, AL      13.1
# 230                 Cedar Rapids, IA      13.2
# 231                 Jacksonville, FL      13.2
# 232                    Rochester, NY      13.3
# 233                    Kalamazoo, MI      13.4
# 234                  Los Angeles, CA      13.4
# 235                     Longview, TX      13.5
# 236                      Sherman, TX      13.5
# 237                    Charlotte, NC      13.6
# 238                     Lewiston, ME      13.6
# 239                 Johnson City, TN      13.7
# 240                   Greenville, NC      13.7
# 241                       Auburn, AL      13.8
# 242                   Sacramento, CA      13.9
# 243                     Portland, OR      14.0
# 244                      Deltona, FL      14.0
# 245                      Lansing, MI      14.1
# 246                  Gainesville, GA      14.1
# 247                  Little Rock, AR      14.2
# 248                    Lexington, KY      14.3
# 249                    Cleveland, OH      14.5
# 250                      Dubuque, IA      14.5
# 251                     Missoula, MT      14.6
# 252                   Greensboro, NC      14.6
# 253                       Monroe, MI      14.6
# 254                       Oxnard, CA      14.6
# 255                      Atlanta, GA      14.8
# 256                   Pittsburgh, PA      14.8
# 257                    Milwaukee, WI      15.0
# 258                   Alexandria, LA      15.0
# 259                     Lakeland, FL      15.0
# 260                   Wilmington, NC      15.2
# 261                 The Villages, FL      15.2
# 262                      Detroit, MI      15.3
# 263                Warner Robins, GA      15.4
# 264                San Francisco, CA      15.5
# 265                        Tyler, TX      15.7
# 266                   Morristown, TN      15.8
# 267                     Savannah, GA      16.3
# 268                  Bloomington, IL      16.4
# 269                         Bend, OR      16.4
# 270                    Nashville, TN      16.4
# 271                     Valdosta, GA      16.5
# 272                   Santa Rosa, CA      16.5
# 273                        Tampa, FL      16.6
# 274              Barnstable Town, MA      16.6
# 275             East Stroudsburg, PA      16.6
# 276                  Great Falls, MT      16.7
# 277                       Eugene, OR      16.8
# 278                        Tulsa, OK      16.9
# 279                    San Diego, CA      17.0
# 280                   Charleston, SC      17.2
# 281                      Spokane, WA      17.2
# 282                  Carson City, NV      17.3
# 283                      Seattle, WA      17.3
# 284                     San Jose, CA      17.4
# 285                  Santa Maria, CA      17.4
# 286                        Provo, UT      17.5
# 287                       Albany, GA      17.5
# 288                    El Centro, CA      17.6
# 289                    Ann Arbor, MI      17.6
# 290                    Jonesboro, AR      17.6
# 291                   Boise City, ID      17.9
# 292                         Yuma, AZ      17.9
# 293                  Chattanooga, TN      18.5
# 294                  New Orleans, LA      18.5
# 295               Port St. Lucie, FL      18.8
# 296                    Cleveland, TN      19.0
# 297                        Logan, UT      19.1
# 298                Michigan City, IN      19.2
# 299                     Appleton, WI      19.6
# 300                      Orlando, FL      19.9
# 301                        Ogden, UT      20.0
# 302                     Stockton, CA      20.3
# 303                     Anniston, AL      20.4
# 304                       Athens, GA      20.8
# 305                    Knoxville, TN      21.2
# 306                    Watertown, NY      21.3
# 307                    La Crosse, WI      21.3
# 308                     Portland, ME      21.5
# 309                     Florence, AL      21.6
# 310                   Morgantown, WV      21.6
# 311                     Bismarck, ND      21.7
# 312                   Santa Cruz, CA      21.8
# 313                    Sebastian, FL      21.9
# 314                         Waco, TX      22.3
# 315                   Huntsville, AL      22.9
# 316                  Grants Pass, OR      23.4
# 317                      Winston, NC      23.5
# 318                  Fond du Lac, WI      23.5
# 319                 Mount Vernon, WA      23.6
# 320                Wichita Falls, TX      24.1
# 321                       Albany, OR      24.3
# 322                         Rome, GA      24.5
# 323                      Medford, OR      24.8
# 324                    Bremerton, WA      24.9
# 325              San Luis Obispo, CA      24.9
# 326                       Bangor, ME      25.0
# 327                    Sheboygan, WI      25.0
# 328                     Longview, WA      25.4
# 329                       Kokomo, IN      26.2
# 330                    Brunswick, GA      26.4
# 331                 Fort Collins, CO      26.6
# 332                       Madera, CA      27.2
# 333                    Fairbanks, AK      27.3
# 334                     Santa Fe, NM      27.6
# 335                      Decatur, AL      28.0
# 336                       Wausau, WI      28.9
# 337               Grand Junction, CO      28.9
# 338                      Madison, WI      29.0
# 339                       Lawton, OK      29.3
# 340                    Manhattan, KS      29.3
# 341                      Oshkosh, WI      29.4
# 342                   Bellingham, WA      29.4
# 343           Hilton Head Island, SC      30.2
# 344                    Corvallis, OR      30.3
# 345                        Chico, CA      31.2
# 346                    Texarkana, TX      31.6
# 347                     Lewiston, ID      32.0
# 348               Corpus Christi, TX      32.3
# 349                      Vallejo, CA      35.2
# 350                       Elmira, NY      36.3
# 351                     Syracuse, NY      36.7
# 352                      Mankato, MN      37.6
# 353                Coeur d'Alene, ID      37.6
# 354                   Pine Bluff, AR      37.8
# 355              Prescott Valley, AZ      38.2
# 356                   Eau Claire, WI      39.0
# 357               Urban Honolulu, HI      40.6
# 358                       Ithaca, NY      43.1
# 359                      Midland, TX      45.6
# 360                     Columbia, MO      57.5
# 361                    Yuba City, CA      62.4
# 362                      Olympia, WA      68.4
# 363                     Lawrence, KS      88.9
# 364                 Fayetteville, AR      97.6
# 365                  Springfield, MO     162.9
# 366               Jefferson City, MO     433.2
